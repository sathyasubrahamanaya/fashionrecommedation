# %%
# !pip install opendatasets
import opendatasets as od
od.download("https://www.kaggle.com/datasets/paramaggarwal/fashion-product-images-small")
# Out:
# ...
# Skipping, found downloaded files in "./fashion-product-images-small" (use force=True to force download)

# %%
import shutil
shutil.rmtree("/kaggle/working/fashion-product-images-small/myntradataset")

# %%
import tensorflow
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input
from tensorflow.keras.layers import GlobalMaxPooling2D
model=ResNet50(weights='imagenet',include_top=False,input_shape=(224,224,3))
model.trainable=False
model.summary()
# Out:
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_pad (ZeroPadding2D) │ (None, 230, 230, 3)    │              0 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 112, 112, 64)   │          9,472 │ conv1_pad[0][0]        │
# ...

# %%
model=tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling2d_1               │ (None, 2048)                │               0 │
# │ (GlobalMaxPooling2D)                 │                             │                 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
import cv2
import numpy as np
from numpy.linalg import norm

def extract_feature(img_path,model):
    img = cv2.imread(img_path)
    img=cv2.resize(img,(224,224))
    img =np.array(img)
    expand_img=np.expand_dims(img,axis=0)
    pre_image=preprocess_input(expand_img)
    result=model.predict(pre_image).flatten()
    normalized=result/norm(result)
    return normalized

# %%
extract_feature('/kaggle/working/fashion-images/data/Apparel/Boys/Images/images_with_product_ids/10054.jpg',model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# array([0.        , 0.12532306, 0.02449397, ..., 0.        , 0.01604249,
#        0.0263424 ], dtype=float32)

# %%
# data is mixed for diversity , and we are not using any textual description , only extract the spatial context
import os
import shutil

def extract_images(source_dir, destination_dir):
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)
    for root, _, files in os.walk(source_dir):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
                source_path = os.path.join(root, file)
                destination_path = os.path.join(destination_dir, file)
                shutil.copy2(source_path, destination_path)  # copy2 preserves metadata


# Example usage: Replace with your actual directories
source_directory = "/kaggle/working/fashion-product-images-small/images"  # Replace with the actual directory containing images
destination_directory = "/kaggle/working/extracted_images" #Replace with your desired destination

extract_images(source_directory, destination_directory)

# %%
len(os.listdir(destination_directory))
# Out:
# 44441

# %%
import os
from tqdm import tqdm
path=r'/kaggle/working/extracted_images'
filename=[]
feature_list=[]

for file in os.listdir(path):
    filename.append(os.path.join(path,file))

for file in filename:
    feature_list.append(extract_feature(file,model))
    print(len(feature_list),"files processed")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 3 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 5 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 6 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 7 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 8 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 9 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 10 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 11 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 12 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 13 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 14 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 15 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 16 files processed
# ...

# %%
for file in os.listdir(path)[1000:2000]:
    filename.append(os.path.join(path,file))

for file in filename:
    feature_list.append(extract_feature(file,model))
    print(len(feature_list),"files processed")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1001 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1002 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1003 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1004 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1005 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1006 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1007 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1008 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1009 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1010 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1011 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1012 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1013 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1014 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1015 files processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# ...

# %%
len(filename)
# Out:
# 44441

# %%
import pickle
pickle.dump(feature_list,open('featurevector.pkl','wb'))
pickle.dump(filename,open('filenames.pkl','wb'))

# %%
model.save("resnet_fashion.keras")

# %%
extracted_images = "/kaggle/working/extracted_images"

# %%
import zipfile
import os
import sys

def zipfolder(foldername, target_dir):            
    zipobj = zipfile.ZipFile(foldername + '.zip', 'w', zipfile.ZIP_DEFLATED)
    rootlen = len(target_dir) + 1
    for base, dirs, files in os.walk(target_dir):
        for file in files:
            fn = os.path.join(base, file)
            zipobj.write(fn, fn[rootlen:])

zipfolder('images', extracted_images) #insert your variables here

# %%
filename[:5]
# Out:
# ['/kaggle/working/extracted_images/57508.jpg',
#  '/kaggle/working/extracted_images/4936.jpg',
#  '/kaggle/working/extracted_images/59795.jpg',
#  '/kaggle/working/extracted_images/49047.jpg',
#  '/kaggle/working/extracted_images/5765.jpg']

# %%
import pickle
#for adding new files to the pkl all we need to do is load the feature vector file and file names files and add new image
def add_files(feature_vector_list,filename_list,image_path_list,model):
    for image_path in image_path_list:
          feature_vector = extract_feature(image_path,model)
          feature_vector_list.append(feature_vector)
          filename_list.append(filename)
          return feature_vector_list, filename_list
    
def load_feature_pkl():
     feature_list = np.array(pickle.load(open('featurevector (1).pkl', 'rb')))
     filenames = pickle.load(open('filenames (2).pkl', 'rb'))
     return list(feature_list), filenames
def save_feature_pkl():   
    pickle.dump(feature_list,open('featurevector.pkl','wb'))
    pickle.dump(filename,open('filenames.pkl','wb'))
